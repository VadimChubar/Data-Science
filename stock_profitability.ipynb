# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("my_data.csv")

# %%
df.columns = ['moment', 'A', 'B', 'C']

# %%
A = [25, -10, 10, 5, 35, 13]
B = [0, 15, -5, 5, 20, 25]

sns.set_style('whitegrid')
sns.regplot(x = A, y = B)
plt.show()

# %%
sns.set_style('whitegrid')
sns.regplot(x = A, y = C)
plt.show()

# %%
sns.set_style('whitegrid')
sns.regplot(x = B, y = C)
plt.show()
